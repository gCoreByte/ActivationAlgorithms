# %% [markdown]
# Imports

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %% [markdown]
# Load data

# %%
df_train = pd.read_csv("../../../Data/dont-overfit-ii/train.csv", index_col='id')
df_test = pd.read_csv("../../../Data/dont-overfit-ii/test.csv", index_col='id')

target_train = df_train.pop('target')
data_train = tf.data.Dataset.from_tensor_slices((df_train.values, target_train.values))
data_train = data_train.shuffle(len(df_train)).batch(1)

data_test = df_test.to_numpy()
#data_test = tf.data.Dataset.from_tensor_slices(df_train.values)
#data_test = data_test.shuffle(len(df_test))

# %% [markdown]
# Build model (sigmoid)

# %%
model = Sequential()
model.add(Dense(64, input_dim=300))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(1, activation='elu'))

es_callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

model.compile(optimizer='adam', loss='binary_crossentropy')

model.fit(data_train, epochs=10, callbacks=[es_callback])
# Out:
# Epoch 1/10
# 250/250 [==============================] - 2s 9ms/step - loss: 6.0160
# Epoch 2/10
# 250/250 [==============================] - 1s 3ms/step - loss: 4.8583
# Epoch 3/10
# 250/250 [==============================] - 1s 3ms/step - loss: 3.9965
# Epoch 4/10
# 250/250 [==============================] - 1s 3ms/step - loss: 4.1235
# Epoch 5/10
# 250/250 [==============================] - 1s 3ms/step - loss: 3.4791
# Epoch 6/10
# 250/250 [==============================] - 1s 3ms/step - loss: 3.3710
# Epoch 7/10
# 250/250 [==============================] - 1s 4ms/step - loss: 3.2677
# Epoch 8/10
# 250/250 [==============================] - 1s 3ms/step - loss: 2.9741
# Epoch 9/10
# 250/250 [==============================] - 1s 3ms/step - loss: 3.0650
# Epoch 10/10
# 250/250 [==============================] - 1s 3ms/step - loss: 2.8837

# %% [markdown]
# Generate validation data, submitted to Kaggle.com

# %%
sol_test = model.predict_classes(data_test)
print(sol_test)

x = 250
y = 0

file = open("../solutions/FNN-overfit/sol-overfit-elu.csv", "w")
file.write("id,target\n")
for y in sol_test:
    file.write(str(x) + "," + str(y).strip("[]") + "\n")
    x += 1
file.close()

# Avg -
# Out:
# [[1]
#  [0]
#  [0]
#  ...
#  [1]
#  [1]
#  [0]]
